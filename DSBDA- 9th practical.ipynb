# %% [markdown]
#                                                          Practical N0=9

# %% [markdown]
# Aim- use the inbuilt dataset 'titanic'.Plot a boxplot for distribution of age with respect each gender along with the information about whether the survived or not

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset('titanic')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='sex', y='age', hue='survived', data=titanic)
plt.title('Age Distribution by Gender and Survival Status')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# Name - Nitesh Lad
#
# Roll_No-13224
